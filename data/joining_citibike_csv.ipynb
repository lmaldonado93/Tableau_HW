# %%
import pandas as pd

# %%
Jan = pd.read_csv("201801-citibike-tripdata.csv")
Feb = pd.read_csv("201802-citibike-tripdata.csv")
Mar = pd.read_csv("201803-citibike-tripdata.csv")
Apr = pd.read_csv("201804-citibike-tripdata.csv")
May = pd.read_csv("201805-citibike-tripdata.csv")
Jun = pd.read_csv("201806-citibike-tripdata.csv")
Jul = pd.read_csv("201807-citibike-tripdata.csv")
Aug = pd.read_csv("201808-citibike-tripdata.csv")
Sep = pd.read_csv("201809-citibike-tripdata.csv")
Oct = pd.read_csv("201810-citibike-tripdata.csv")
Nov = pd.read_csv("201811-citibike-tripdata.csv")
Dec = pd.read_csv("201812-citibike-tripdata.csv")

# %%
Year_2018 = pd.concat([Jan, Feb, Jun, Jul, Aug, Dec])

# %%
Year_2018.to_csv('2018_citibike_tripdata.csv')

# %%
Year_2018.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1           723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2           496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3           306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4           306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    start station id start station name  start station latitude  \
# 0              72.0   W 52 St & 11 Ave               40.767272
# 1              72.0   W 52 St & 11 Ave               40.767272
# 2              72.0   W 52 St & 11 Ave               40.767272
# 3              72.0   W 52 St & 11 Ave               40.767272
# 4              72.0   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929           505.0          6 Ave & W 33 St
# ...

# %%
Year_2018.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1           723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2           496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3           306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4           306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    start station id start station name  start station latitude  \
# 0              72.0   W 52 St & 11 Ave               40.767272
# 1              72.0   W 52 St & 11 Ave               40.767272
# 2              72.0   W 52 St & 11 Ave               40.767272
# 3              72.0   W 52 St & 11 Ave               40.767272
# 4              72.0   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929           505.0          6 Ave & W 33 St
# ...

# %%
Year_2018= Year_2018.replace({'gender': {0: "Unknown", 1: "Male", 2: "Female"}})

# %%
Year_2018.to_csv('2018_citibike_tripdata.csv')

# %%
Year_2018
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1                 723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2                 496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3                 306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4                 306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
# 5                1602  2018-01-01 21:31:54.1920  2018-01-01 21:58:36.3530
# 6                 722  2018-01-02 07:54:53.6460  2018-01-02 08:06:55.8720
# 7                 434  2018-01-02 08:06:14.3310  2018-01-02 08:13:28.7670
# 8                 366  2018-01-02 08:10:15.2550  2018-01-02 08:16:21.8960
# 9                 324  2018-01-02 08:13:30.8960  2018-01-02 08:18:55.1200
# 10               1155  2018-01-02 09:15:29.9050  2018-01-02 09:34:45.0200
# 11               1200  2018-01-02 10:23:18.8800  2018-01-02 10:43:18.9110
# ...
